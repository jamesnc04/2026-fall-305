# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesnc04/2026-fall-305/blob/main/cost_behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cost Behavior Analysis
# ## Cost Accounting I - Riverbend Manufacturing
#
# We have 24 months of produciotn and cost data.
# Our job is to work out how each cost behaves when the number of units produced changes.
#
# Cost driver (activity base): Units_Produced

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv('/content/cost_behavior_data.csv')
df = pd.read_csv('https://raw.githubusercontent.com/jamesnc04/2026-fall-305/main/cost_behavior_data.csv')
print("Rows and columns:", df.shape)

# display(df.info())
# display(df.describe())
# display(df.head())
# display(df.head() df.tail() df.iloc[#], sample)
# Out:
# Rows and columns: (24, 9)
